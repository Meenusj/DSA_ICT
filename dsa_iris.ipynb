# %% [markdown]
# <a href="https://colab.research.google.com/github/Meenusj/DSA_ICT/blob/main/dsa_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  Read the dataset

# %%
data=pd.read_excel('iris.xls')
print(data.head())
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# columns in the dataset

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# Mean

# %%
# Calculate the mean for each column
means = data.mean()

print("Mean for each column:")
print(means)
# Out:
# Mean for each column:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
# <ipython-input-5-5199ec649f1e>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = data.mean()

# %% [markdown]
# check null value

# %%
null_value=data.isnull()
print("null values:",null_value)
# Out:
# null values:         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
# Check for null values
null_values = data.isnull().sum()

print("Null values in the dataset:")
print(null_values)
# Out:
# Null values in the dataset:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
iris_df = sns.load_dataset('iris')
iris_df = iris_df.rename(columns={'sepal_length': 'sl', 'sepal_width': 'sw', 'petal_length': 'pl', 'petal_width': 'pw'})

# %% [markdown]
# pair plot

# %%
sns.pairplot(iris_df, hue='species', vars=['sl', 'sw', 'pl', 'pw'], diag_kind='hist')
plt.show()

# %% [markdown]
# Box plot

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=iris_df, x='species', y='sl')
plt.title('Distribution of Sepal Length for Different Species')
plt.show()

# %% [markdown]
# Bar chart

# %%
mean_values = iris_df.groupby('species').mean()

features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

plt.figure(figsize=(10, 6))

for i, feature in enumerate(features, start=1):
    plt.subplot(2, 2, i)
    sns.barplot(data=mean_values.reset_index(), x='species', y=feature)
    plt.title(f'Mean {feature.capitalize()} by Species')

plt.tight_layout()
plt.show()

# %% [markdown]
# Scatter plot

# %%
# Visualization 1: Sepal Length vs Sepal Width
plt.figure(figsize=(8, 6))
sns.scatterplot(data=iris_df, x='sepal_length', y='sepal_width', hue='species', palette='Set1')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend(title='Species')
plt.show()

# Visualization 2: Petal Length vs Petal Width
plt.figure(figsize=(8, 6))
sns.scatterplot(data=iris_df, x='petal_length', y='petal_width', hue='species', palette='Set2')
plt.title('Petal Length vs Petal Width')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.legend(title='Species')
plt.show()

# Visualization 3: Sepal Length vs Petal Length
plt.figure(figsize=(8, 6))
sns.scatterplot(data=iris_df, x='sepal_length', y='petal_length', hue='species', palette='Set3')
plt.title('Sepal Length vs Petal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.legend(title='Species')
plt.show()

# %% [markdown]
# pie chart

# %%
# Count the number of samples for each species
species_counts = iris_df['species'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set3'))
plt.title('Proportion of Each Iris Species')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
